# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.font_manager as fm
# 获取所有字体路径
font_paths = fm.findSystemFonts()

# 打印所有可用字体
for font in font_paths:
    print(fm.FontProperties(fname=font).get_name())
# Out:
# ITF Devanagari
# Galvji
# Noto Sans Old Italic
# STIXNonUnicode
# Malayalam Sangam MN
# Hiragino Sans GB
# Arial Unicode MS
# Hoefler Text
# PingFang HK
# Arima Koshi
# Yuanti SC
# Noto Sans Pau Cin Hau
# PilGi
# Iowan Old Style
# Noto Sans Manichaean
# Sukhumvit Set
# Silom
# Noto Sans Limbu
# Gujarati Sangam MN
# Noto Sans Old Turkic
# Sathu
# Adelle Sans Devanagari
# Damascus
# Arial Narrow
# Noto Sans Modi
# Symbol
# Noto Sans Kannada
# PT Mono
# .SF Compact Rounded
# Hannotate SC
# BM Yeonsung
# .SF Arabic
# Apple Braille
# Lao Sangam MN
# Times
# Tiro Telugu
# Noto Sans Mahajani
# Gotu
# Baloo 2
# Heiti TC
# Noto Sans Gunjala Gondi
# .SF Georgian Rounded
# Apple Braille
# Noto Sans Takri
# Baloo Tamma 2
# Didot
# SimSong
# Noto Sans Lydian
# Bai Jamjuree
# Songti SC
# Kavivanar
# DecoType Naskh
# Baloo Thambi 2
# Noto Sans Gothic
# Noto Sans Glagolitic
# Bodoni 72
# Hiragino Maru Gothic Pro
# DIN Condensed
# KoHo
# Noto Sans Armenian
# Nadeem
# Chalkboard
# Noto Sans Lycian
# ...

# %%
# 设置中文字体
plt.rcParams['font.family'] = 'Wawati SC'  # 或者 'SimHei', 'STHeiti' 等
plt.rcParams['axes.unicode_minus'] = False  # 处理负号显示问题
original_data =  pd.read_csv("./Data/penguins.csv")

# %%
original_data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
s1 = original_data["culmen_length_mm"]

# %%
sns.histplot(s1)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Count'>

# %%
sns.kdeplot(s1)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.boxplot(s1)
# Out:
# <Axes: ylabel='culmen_length_mm'>

# %%
sns.violinplot(s1)
# Out:
# <Axes: ylabel='culmen_length_mm'>

# %%
sns.histplot(original_data,x="culmen_length_mm")
plt.title("Adelie企鹅样本的嘴嘴长度分布")
plt.xlabel("嘴长度（单位：mm）")
plt.ylabel("样本数量")
# Out:
# Text(0, 0.5, '样本数量')
